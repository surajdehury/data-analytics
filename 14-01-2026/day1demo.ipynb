# %%
"Hello World"
# Out:
# 'Hello World'

# %%
#single line comment 
'''This is 
multline comment'''
#syntax for adding comments
# Out:
# 'This is \nmultline comment'

# %%
#Displaying outputs on to the screen
#print
print("Hello all ")
# Out:
# Hello all

# %%
print('Hello devi')
# Out:
# Hello devi

# %%
print('''Hi
Hello all
Good Morning''')
# Out:
# Hi
# Hello all
# Good Morning

# %%
#variable
#named memory location to store data
#rules of identifier
#1.can be alphanumeric but cannot start with a digit
#2.cannot have special character otherthan underscore
#3.case sensisitive
#4.cannot use keywords(pre defined words) as an identifier

a=5
b=3
c=a+b
print (c)
print(a,c)
# Out:
# 8
# 5 8

# %%
#a=5 and c=8
print ('a=',a,'and c=',c)
# Out:
# a= 5 and c= 8

# %%
#formating of print
print('a={} and c={}'.format(a,c))
# Out:
# a=5 and c=8

# %%
'''Create three variables x,y,z respectively
to store three integers.Display the variables along with their contents'''
x=2
y=5
z=7
print('x=',x,',y=',y,'and z=',z)
print('x={0} ,y={1} and z={2}'.format(x,y,z))
# Out:
# x= 2 ,y= 5 and z= 7
# x=2 ,y=5 and z=7

# %%
x,y,z=10,20,30
print('x={0} ,y={1} and z={2}'.format(x,y,z))
# Out:
# x=10 ,y=20 and z=30

# %%
#Data types
#Numeric
    #int
    #float
    #complex

# %%
a=10

# %%
#check data type -----type
type(a)
# Out:
# int

# %%
#python is a dynamicallyt typed pgm language
a=45.67
type(a)
# Out:
# float

# %%
a=3+5J
type(a)
# Out:
# complex

# %%
#sequence types
#an ordered collection of data
#strings
#list
#tuples

# %%
#handling a strings
#create a string
s1='a' #s1="a"
s2='hello' #s2="hello"
s3='''hi
hlo'''

# %%
type(s1)
type(s2)
type(s3)
# Out:
# str

# %%
print(s2)
# Out:
# hello

# %%
#indexing/string slicing
s2[0]
# Out:
# 'h'

# %%
s2[-1]
# Out:
# 'o'

# %%
s2[-3]
# Out:
# 'l'

# %%
s2[1]
# Out:
# 'e'

# %%
print(s2[0:2:1])
# Out:
# he

# %%
print(s2[0:2])
# Out:
# he

# %%
s="hello all"
#reverse the string
print(s[-1:-10:-1])
# Out:
# lla olleh

# %%
s[0]="s"
print(s)
#immutable data type,cannot chnage string once cretaed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 s[0]="s"
#       2 print(s)
#       3 #immutable data type,cannot chnage string once cretaed
#
# TypeError: 'str' object does not support item assignment

# %%
#len ----string length
print("string length of s=",len(s))
# Out:
# string length of s= 9

# %%
#string concatenation
s1="hi"
s2="hello"
print(s1+s2)
# Out:
# hihello

# %%
#string copy
s=s1
print(s)
# Out:
# hi

# %%
l1=[]#empty set

# %%
type(l1)
# Out:
# list

# %%
l2=[2,3,4,5,6]
type(l2)
# Out:
# list

# %%
l2=[1,1,'hi',5.67,9+9j]
type(l2)
# Out:
# list

# %%
#access list
print(l2)
# Out:
# [1, 1, 'hi', 5.67, (9+9j)]

# %%
print(l2[-1])
# Out:
# (9+9j)

# %%
l2[0]=100
print(l2)
# Out:
# [100, 1, 'hi', 5.67, (9+9j)]

# %%
#len
print(len(l2))
# Out:
# 5

# %%
#append
l2.append(200)
print(l2)
# Out:
# [100, 1, 'hi', 5.67, (9+9j), 200]

# %%
l2.append(2J+6)

# %%
#insert 
#add a ingle element to a specifie psotition
l2.insert(1,69)

# %%
print(l2)
# Out:
# [100, 69, 1, 'hi', 5.67, (9+9j), 200, (6+2j)]

# %%
#extend
#adds multiplke elements at the end of thge list
l2.extend([1,2,3])
print(l2)
# Out:
# [100, 69, 1, 'hi', 5.67, (9+9j), 200, (6+2j), 1, 2, 3]
