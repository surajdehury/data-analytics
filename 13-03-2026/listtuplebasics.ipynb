# %%
l=[1,2,3,4,5,1,1,2]

# %%
#remove
#remove a specific element from list
l.remove(1)
print(l)
# Out:
# [2, 3, 4, 5, 1, 1, 2]

# %%
#pop
#removes an element based on the index
l.pop(3)#remove the ele at index 3
print(l)
# Out:
# [2, 3, 4, 1, 2]

# %%
#del keyword that is used to delete the data
del l[0]
print(l)
# Out:
# [4, 1, 2]

# %%
#tuple
#ordered collection of similar and different types of data
#immutable data types

# %%
t1=(1,2,3,4)
type(t1)
# Out:
# tuple

# %%
print(t1)
# Out:
# (1, 2, 3, 4)

# %%
t2=(100,100,2.34,6+6j,"hii")
type(t2)
# Out:
# tuple

# %%
#access tuple ele
print(t2[0])
# Out:
# 100

# %%
print(t2[-1])
print(t2[0:5:1])
# Out:
# hii
# (100, 100, 2.34, (6+6j), 'hii')

# %%
t2[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t2[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#nested list
#list within a list
l=[1,2,3,[100,200],['a',25]]

# %%
#access inner list
print(l[3])
print(l[3][0])
# Out:
# [100, 200]
# 100

# %%
t=([1,2,3],4,5)

# %%
t[0]
# Out:
# [1, 2, 3]

# %%
t[0][0]=100
print(t)
# Out:
# ([100, 2, 3], 4, 5)

# %%
#typecasting
#changing one data types to another

# %%
a=100
type(a)
# Out:
# int

# %%
a=float(a)
type(a)
# Out:
# float

# %%
print(a)
# Out:
# 100.0

# %%
ss="hello"
l1=list(ss)
type(l1)
# Out:
# list

# %%
print(l1)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
ss="hello"
t1=tuple(ss)

# %%
l=[1,2,3]
s=str(l)
print(s)
# Out:
# [1, 2, 3]

# %%
type(s)
# Out:
# str

# %%
s[1]
# Out:
# '1'

# %%
s[2]
# Out:
# ','

# %%
#Dictonary 
#unordered collection of data
#key value pairs
#mutable data types
#key----unique
#values---duplicate
#creating a dictionary
d1={"Name":"xxx","ID":123,"Marks":[100,88]}

# %%
type(d1)
# Out:
# dict

# %%
print(d1)
# Out:
# {'Name': 'xxx', 'ID': 123, 'Marks': [100, 88]}

# %%
#Accessing ele
d1["Name"]
# Out:
# 'xxx'

# %%
d1["ID"]
# Out:
# 123

# %%
#get is a fuction to access another way
d1.get("Name")
# Out:
# 'xxx'

# %%
d1['Name']='yyyy'
print(d1)
# Out:
# {'Name': 'yyyy', 'ID': 123, 'Marks': [100, 88]}

# %%
d1['Marks'][0]=88
print(d1)
# Out:
# {'Name': 'yyyy', 'ID': 123, 'Marks': [88, 88]}

# %%
d1['PhoneNumber']=999999
print(d1)
# Out:
# {'Name': 'yyyy', 'ID': 123, 'Marks': [88, 88], 'PhoneNumber': 999999}

# %%
#remove elemets use DEL
del d1['PhoneNumber']
print(d1)
# Out:
# {'Name': 'yyyy', 'ID': 123, 'Marks': [88, 88]}

# %%
#Nested Dictionary
d2={1:100,2:{'A':100,'B':200}}

# %%
print(d2)
# Out:
# {1: 100, 2: {'A': 100, 'B': 200}}

# %%
d2[2]['A']
# Out:
# 100

# %%
#set
#unordered collection of data
#mutuable data type
#unique elements

# %%
#create a set
s1={1,2,3,4}

# %%
print(s1)
# Out:
# {1, 2, 3, 4}

# %%
s2=set([100,200,3.45])

# %%
type(s2)
# Out:
# set

# %%
s3=set("hello")
print(s3)
# Out:
# {'o', 'e', 'l', 'h'}

# %%
s={}
type(s)
# Out:
# dict

# %%
s=set()

# %%
s3=set("HELlO")
print(s3)
# Out:
# {'H', 'O', 'l', 'L', 'E'}

# %%
#access set ele
#loops

# %%
#add
#adds an ele to a set
s.add(100)
print(s)
# Out:
# {100}

# %%
s.add(23)
s.add(8.89)
print(s)
# Out:
# {8.89, 100, 23}

# %%
#update
#adds multiple elements to set
s.update([12,44,89])
print(s)
# Out:
# {100, 8.89, 12, 44, 23, 89}

# %%
#discard
s.discard(89)
print(s)
# Out:
# {100, 8.89, 12, 44, 23}

# %%
#bool
#boolean data
#True
#False
a=True
type(a)
# Out:
# bool

# %%
b=False
type(b)
# Out:
# bool

# %%
#conditional statements
#relational/comparison operators
#> greater than
#<less than
#== equality
#!= not equal to
#>= greater than or equal to
#<= less than or equal to

# %%
a=10
b=20
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# True

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %%
print(a>=b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %%
#if
#if else
#if elif else

# %%
x=100
if(x>0):
    print("x=",x)
    print("x is positive")
print("Outside")
# Out:
# x= 100
# x is positive
# Outside

# %%
x=-1
if(x>0):
    print("x=",x)
    print("x is positive")
print("Outside")
# Out:
# Outside

# %%
if(x>0):
    print("x=",x)
    print("x is positive")
else:
    print("x=",x)
    print("x is negtive")
# Out:
# x= -1
# x is negtive

# %%
x=100
if(x>0):
    print("x=",x)
    print("x is positive")
else:
    print("x=",x)
    print("x is negtive")
# Out:
# x= 100
# x is positive

# %%
x=5
if(x==5):
    print("x is equivalent to 5")
elif(x>5):
    print("x is greater than 5")
else:
    print("x is less than 5")
# Out:
# x is equivalent to 5

# %%
x=1
if(x==5):
    print("x is equivalent to 5")
elif(x>5):
    print("x is greater than 5")
else:
    print("x is less than 5")
# Out:
# x is less than 5

# %%
x=9
if(x==5):
    print("x is equivalent to 5")
elif(x>5):
    print("x is greater than 5")
else:
    print("x is less than 5")
# Out:
# x is greater than 5

# %%
#loops
#while
#for

# %%
x=5
while(x>0):
    print("x=",x)
    x=x-1
# Out:
# x= 5
# x= 4
# x= 3
# x= 2
# x= 1
