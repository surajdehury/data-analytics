# %% [markdown]
# # The finally Block

# %%
#the finally block is always executed

# %%
try:
    #code
except:
    #code
finally:
    #code

# %%
try:
    file=open('data.csv',"r")
    content=file.read()
    #code
except Exception as e:
    #code
finally:
    file.close()
