# %%
#PQ 15

# %%
#Done

# %%
"""Question 1
0 / 0 pts
What is the default data type of args and kwargs?
  list, tuple 
  tuple, list 
  tuple, dictionary 
You have selected the correct response.
  list, dictionary 
 
Question 2
0 / 0 pts
Which of the following character is used to give single-line comments in Python?

 

  # 
You have selected the correct response.
  // 
  ! 
  /* 
 
Question 3
0 / 0 pts
Which of the following character is used to give multi-line comments in Python?

 

  /* 
  
  Python inherently does not support multi-line comments. 
  both b and c 
You have selected the correct response.
 
Question 4
0 / 0 pts
What would be the Code output?

' '.join([[0], [1]])

  ('[0] [1]',) 
  ('01') 
  '0 1' 
  TypeError 
You have selected the correct response. 
 
Question 5
0 / 0 pts
What is the output of the following display_person() function call?

def display_person(*args):

       for i in args:

             print(i)

display_person(name="Ram", height=209)

  TypeError 
  Ram
209
You have selected the correct response.
  nameage 
  None of the above 
 
Question 6
0 / 0 pts
Choose the function declaration of fun1() so that we can execute the following function calls successfully

fun1(25, 75, 55)

fun1(10, 20)

  def fun1(**kwargs) 
  It is not possible in Python 
  def fun1(*args) 
You have selected the correct response.
  def fun1(*data) 
 
Question 7
0 / 0 pts
What is the output of the following function calling

def add (number):

      return number + 25

ans = add(5)

print(number)

  25 
  5 
  NameError 
You have selected the correct response
  30 
 
Question 8
0 / 0 pts
Python allows a user to create anonymous functions at runtime. This type of function is called:
  lambda 
You have selected the correct response.
  anonymous 
  alpha 
  None of the above 
 
Question 9
0 / 0 pts
Lambda functions have to return a value for a validated input.
  TRUE 
You have selected the correct response.
  FALSE 
 
Question 10
0 / 0 pts
What is the output?

func = lambda x: return x print(func(2))

  x 
  2 
  2 
  SyntaxError 
You have selected the correct response.
"""
