# %% [markdown]
# # Error Handling

# %%
"""Allows programmers to handle error which may occur during the execution of the program
    Two types of Errors:
        Syntax Error:
            Count=0
            while count <5  ->Missing ":"
                print count   ->Missing parenthesis "()"
                count+=1
        Exeception Parenthesis:
        Basically occurs at the time of execution.

# %% [markdown]
# ## Try except Block

# %%
try:
    #code
except ExceptionType:
    #code

# %%
def square():
    num=int(input("Enter the integer:"))
    return num**2

# %%
square()
# Out:
# Enter the integer: 8
# 64

# %%
square()
# Out:
# Enter the integer: jjjj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 square()
#
# Cell In[3], line 2, in square()
#       1 def square():
# ----> 2     num=int(input("Enter the integer:"))
#       3     return num**2
#
# ValueError: invalid literal for int() with base 10: 'jjjj'

# %%
def square():
    try:
        num=int(input("Enter the integer:"))
        return num**2
    except ValueError:
        print("Invalid input,Please enter a Integer.")

# %%
square()
# Out:
# Enter the integer: jj
# Invalid input,Please enter a Integer.
