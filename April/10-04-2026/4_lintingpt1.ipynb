# %% [markdown]
# # Linting

# %%
#linting is a process of analyzing a code for potential errors,stylistic errors

# %%
#pylint-python package that provide a static code analysis tool,checking errors,coding standards

# %%
pip install pylint
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 16.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pylint]2m4/6 [astroid]
# ...
# Note: you may need to restart the kernel to use updated packages.
