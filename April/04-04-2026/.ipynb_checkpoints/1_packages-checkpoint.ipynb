# %% [markdown]
# ## Packages

# %% [markdown]
# - A way of organizing related modules and code together in a hierarchical manner.This helps in better management of code and make it more modular and reusable.
