# %%
#PQ-14

# %%
#Done

# %%
"""Question 1
0 / 0 pts
What is a function?
  A reusable piece of code built into python 
  A reusable piece of code that we can create 
  Both of the above 
You have selected the correct response.
  None of the above 
 
Question 2
0 / 0 pts
A python function:
  Can only take a single input and can return only a single output 
  Can only take a single input and can return multiple outputs 
  Can take multiple inputs and can return only a single output 
  Can take multiple inputs and can return multiple outputs 
You have selected the correct response.
 
Question 3
0 / 0 pts
What does the following function return :

def multiply(a):

       return a**2

multiply(3)

  6 
  9 
You have selected the correct response.
  Syntax error 
  None of the above 
 
Question 4
0 / 0 pts
What does the following code print :

def area(length, breadth):

       return length*breadth

       print("Area of the rectangle is ", length*breadth)

a = area(3, 4)

print(a)

  Area of the rectangle is 12 
  Area of the rectangle is 1212 
  12 
You have selected the correct response.
  None of the above 
 
Question 5
0 / 0 pts
What does the following code result in?

def get_y_from_xs(x1, x3, x2=3):

      y = x1 * 10 + x2 * 20 + x3 * 100

      return y

ans = get_y_from_xs(x1 = 10, x3 = 20)

print(ans)

  208000 
  2160 
You have selected the correct response.
  Error 
  None of the above 
 
Question 6
0 / 0 pts
What does the following code result in?

def get_y_from_xs(x1, x2=3, x3):

       y = x1 * 10 + x2 * 20 + x3 * 100

       return y

ans = get_y_from_xs(x1 = 10, x3 = 20)

print(ans)

  208000 
  2160 
  Error 
You have selected the correct response.
  None of the above 
 
Question 7
0 / 0 pts
What does the * denote in *args?
  args is a pointer 
  there are going to be multiple no. of arguments 
You have selected the correct response.
  args contain keys for each argument 
  none of the above 
 
Question 8
0 / 0 pts
In Python, how are arguments passed?
  pass by value 
  pass by assignment 
You have selected the correct response.
  It gives options to user to choose 
  Both A and B 
 
Question 9
0 / 0 pts
A python function always returns a value.
  FALSE 
  TRUE 
You have selected the correct response.
 
Question 10
0 / 0 pts
What will be the output of the following Python code?

def remover(numbers):

       numbers.pop(1)

numbers = [7,8,9]

remover(numbers)

print(numbers)

  [7,8,9] 
  [7,9] 
You have selected the correct response. pop() removes an element with positional arguments 0,1 and so on.
  [8,9] 
  [7,8] """
