# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.13/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv(
    os.path.join(folder_path, file),
    on_bad_lines='skip'
)

# %%
import pandas as pd
import os

folder_path = "/Users/surajsonu07/Desktop/data-analytics/June/21.06.2026/northwind"

with pd.ExcelWriter("northwind.xlsx", engine="openpyxl") as writer:
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            try:
                df = pd.read_csv(
                    os.path.join(folder_path, file),
                    engine='python',
                    on_bad_lines='skip'
                )

                sheet_name = file.replace(".csv", "")[:31]
                df.to_excel(writer, sheet_name=sheet_name, index=False)

                print(f"✅ Added {file}")

            except Exception as e:
                print(f"❌ Error in {file}: {e}")

print("Excel file created successfully!")
# Out:
# ✅ Added order-details.csv
# ✅ Added customers.csv
# ✅ Added categories.csv
# ✅ Added regions.csv
# ✅ Added products.csv
# ✅ Added orders.csv
# ✅ Added suppliers.csv
# ✅ Added employee-territories.csv
# ✅ Added shippers.csv
# ✅ Added territories.csv
# ✅ Added employees.csv
# Excel file created successfully!
