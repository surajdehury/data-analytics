# %%
#Important Operand-'+','-','*','/'

# %%
#Single Division (Python 3.0)
5/2
# Out:
# 2.5

# %%
#Double Division
5//2
# Out:
# 2

# %%
#Modulo (Remainder)
6%2
# Out:
# 0

# %%
#Exponentiation
2**3
# Out:
# 8

# %%
#Power
pow(2,4)
# Out:
# 16

# %%
#Absolute value
abs(-15)
# Out:
# 15

# %%
#Round
round(3.9)
# Out:
# 4

# %%
round(3.3)
# Out:
# 3

# %%
#max & min
min(3,15,3,1)
# Out:
# 1

# %%
max(4,11,22,99)
# Out:
# 99
