# %% [markdown]
# ## **User Input**

# %%
#inbuilt
input()

# %%
name=input("Hi, What's your name:")

print(f"Hello {name},Welcome to the Introduction to Python Series")
# Out:
# Hi, What's your name: Suraj
# Hello Suraj,Welcome to the Introduction to Python Series

# %%
type(name)
# Out:
# str

# %%
age=int(input("What is your age"))

if age>18:
    print("You are adult.")
else:
    print("You are not an adult.")
# Out:
# What is your age 24
# You are adult.

# %%
name=input("Hi, What's your name:")
print(f"Hello {name},Welcome to the Introduction to Python Series")
age=int(input("What is your age"))
if age>18:
    print("You are adult.")
else:
    print("You are not an adult.")
# Out:
# Hi, What's your name: Suraj
# Hello Suraj,Welcome to the Introduction to Python Series
# What is your age 24
# You are adult.
