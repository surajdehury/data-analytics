# %%
student_dict={'name':'Suraj','Class':4,'age':8,'roll_no':1}

# %%
student_dict
# Out:
# {'name': 'Suraj', 'Class': 4, 'age': 8, 'roll_no': 1}

# %%
type(student_dict)
# Out:
# dict

# %%
len(student_dict)
# Out:
# 4

# %%
student_dict.get('Class')
# Out:
# 4

# %%
student_dict.get('age')
# Out:
# 8

# %%
student_dict.items()
# Out:
# dict_items([('name', 'Suraj'), ('Class', 4), ('age', 8), ('roll_no', 1)])

# %%
student_dict.keys()
# Out:
# dict_keys(['name', 'Class', 'age', 'roll_no'])

# %%
student_dict.pop('name')
# Out:
# 'Suraj'

# %%
student_dict
# Out:
# {'Class': 4, 'age': 8, 'roll_no': 1}

# %%
student_dict.popitem()
# Out:
# ('roll_no', 1)

# %%
student_dict.setdefault('marks',0)
# Out:
# 0

# %%
student_dict
# Out:
# {'Class': 4, 'age': 8, 'marks': 0}
