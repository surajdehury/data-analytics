# %%
#Example
name="Suraj"
age=15

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
age=15.5

# %%
type(age)
# Out:
# float

# %%
student_name="Suraj"

# %%
student_age=25

# %%
#str='diod'
int
float
# Out:
# float

# %% [markdown]
# #PYTHON DATA TYPES

# %%
X='SURAJ'

# %%
type(X)
# Out:
# str

# %%
True,False
# Out:
# (True, False)

# %%
type(True)
# Out:
# bool

# %%
x=True
type(x)
# Out:
# bool

# %% [markdown]
# #Mutable & Immutable

# %% [markdown]
# Mutable

# %%
l=[1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
l[1]=5

# %%
l
# Out:
# [1, 5, 3, 4]

# %% [markdown]
# Immutable

# %%
name="Suraj"
name[3]='o'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 name="Suraj"
# ----> 2 name[3]='o'
#
# TypeError: 'str' object does not support item assignment

# %%
name="suraj"

# %%
name
# Out:
# 'suraj'

# %% [markdown]
# Numbers

# %%
a=3
type(a)
# Out:
# int

# %%
b=3.124
type(b)
# Out:
# float

# %%
c=7-7j
type(c)
# Out:
# complex

# %%
#BOOL is basically a binary value that represent either True or False

# %% [markdown]
# Strings
