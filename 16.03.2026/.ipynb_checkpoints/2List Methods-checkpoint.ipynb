# %%
fruits=["apple","banana","orange","grape"]

# %%
fruits.append('pineapple')

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'grape', 'pineapple']

# %%
fruits2=['Mango','Papaya','Kiwi']

# %%
fruits.extend(fruits2)

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'grape', 'pineapple', 'Mango', 'Papaya', 'Kiwi']

# %%
fruits.append('apple')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'orange',
#  'grape',
#  'pineapple',
#  'Mango',
#  'Papaya',
#  'Kiwi',
#  'apple']

# %%
fruits.insert(2,'Kiwi')
fruits
# Out:
# ['apple',
#  'banana',
#  'Kiwi',
#  'orange',
#  'grape',
#  'pineapple',
#  'Mango',
#  'Papaya',
#  'Kiwi',
#  'apple']

# %%
fruits.remove("apple")

# %%
fruits
# Out:
# ['banana',
#  'Kiwi',
#  'orange',
#  'grape',
#  'pineapple',
#  'Mango',
#  'Papaya',
#  'Kiwi',
#  'apple']

# %%
fruits.pop()#from end remove
# Out:
# 'apple'

# %%
fruits.pop(0)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['Kiwi', 'orange', 'grape', 'pineapple', 'Mango', 'Papaya', 'Kiwi']

# %%
fruits.count('Kiwi')
# Out:
# 2

# %%
fruits
# Out:
# ['Kiwi', 'Kiwi', 'Mango', 'Papaya', 'grape', 'orange', 'pineapple']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['Kiwi', 'Kiwi', 'Mango', 'Papaya', 'grape', 'orange', 'pineapple']

# %%
fruits1=fruits.copy()
fruits
# Out:
# ['Kiwi', 'Kiwi', 'Mango', 'Papaya', 'grape', 'orange', 'pineapple']

# %%
fruits1.pop()
# Out:
# 'pineapple'

# %% [markdown]
# Tuple

# %%
t1=(1,2,3,4,4,4)

# %%
type(t1)
# Out:
# tuple

# %%
t1.count(4)
# Out:
# 3

# %% [markdown]
# SET

# %%
s1={1,2,3,4}

# %%
s2=set([1,2,3,4])

# %%
type(s1)
type(s2)
# Out:
# set

# %%
len(s2)
# Out:
# 4

# %%
s1.add(5)

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.add(3)

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.pop()
# Out:
# 1

# %%
s1.pop()
# Out:
# 2

# %%
s1
# Out:
# {3, 4, 5}

# %%
s1.remove(5)

# %%
s1
# Out:
# {3, 4}

# %%
s2=s1.copy()

# %%
s2
# Out:
# {3, 4}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %%
s1={'a','b','c','d','e'}
s2={'b','f','e','g',}

# %%
s=s1.union(s2)

# %%
s
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 'g'}

# %%
s1.intersection(s2)
# Out:
# {'b', 'e'}

# %%
s1.difference(s2)
# Out:
# {'a', 'c', 'd'}
