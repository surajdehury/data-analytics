# %%
#Example
name="Suraj"
age=15

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
age=15.5

# %%
type(age)
# Out:
# float

# %%
student_name="Suraj"

# %%
student_age=25

# %%
#str='diod'
int
float
# Out:
# float

# %% [markdown]
# #PYTHON DATA TYPES

# %%
X='SURAJ'

# %%
type(X)
# Out:
# str

# %%
True,False
# Out:
# (True, False)

# %%
type(True)
# Out:
# bool

# %%
x=True
type(x)
# Out:
# bool

# %% [markdown]
# #Mutable & Immutable

# %% [markdown]
# Mutable

# %%
l=[1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
l[1]=5

# %%
l
# Out:
# [1, 5, 3, 4]

# %% [markdown]
# Immutable

# %%
name="Suraj"
name[3]='o'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 name="Suraj"
# ----> 2 name[3]='o'
#
# TypeError: 'str' object does not support item assignment

# %%
name="suraj"

# %%
name
# Out:
# 'suraj'

# %% [markdown]
# Numbers

# %%
a=3
type(a)
# Out:
# int

# %%
b=3.124
type(b)
# Out:
# float

# %%
c=7-7j
type(c)
# Out:
# complex

# %%
#BOOL is basically a binary value that represent either True or False

# %% [markdown]
# String

# %%
str1='Hello world'

# %%
type(str1)
# Out:
# str

# %%
str2="I love Python"

# %%
str3="""This is the first line.
this is 2nd line"""

# %%
print(str3)
# Out:
# This is the first line.
# this is 2nd line

# %% [markdown]
# String Slicing

# %%
str1="I love Python."# 0,1,2,3,...

# %%
str1[0]
# Out:
# 'I'

# %%
str1[2]
# Out:
# 'l'

# %%
#reverse indexing
#-1,-2,-3,..
str1[-2]
# Out:
# 'n'

# %%
str1[2:5]#lower bound is inclusive and upper bound is exclusive
# Out:
# 'lov'

# %%
str1[2:6]
# Out:
# 'love'

# %%
str1='python'
str1[0:3]
# Out:
# 'pyt'

# %%
str1[0:4]
# Out:
# 'pyth'

# %%
str1[0:-2]
# Out:
# 'pyth'

# %%
str1[2:] #ommit
# Out:
# 'thon'

# %%
str1[:4]
# Out:
# 'pyth'

# %% [markdown]
# String Methods

# %%
str1="Hello Python"

# %%
len(str1)
# Out:
# 12

# %%
str1.upper()
# Out:
# 'HELLO PYTHON'

# %%
str1.lower()
# Out:
# 'hello python'

# %%
str2='  Hello World  '

# %%
str2.strip()
# Out:
# 'Hello World'

# %% [markdown]
# split()

# %%
str3= 'Hello this is suraj'

# %%
str3.split()
# Out:
# ['Hello', 'this', 'is', 'suraj']

# %% [markdown]
# join

# %%
','.join(['Hello', 'this', 'is', 'suraj'])
# Out:
# 'Hello,this,is,suraj'

# %%
str1.isupper()
# Out:
# False

# %%
str1.islower()
# Out:
# False

# %%
str1.isalnum()
# Out:
# False

# %%
str1.isdigit()
# Out:
# False

# %%
str1.isalpha()
# Out:
# False

# %%
str1='python'

# %% [markdown]
# LIST

# %%
fruits=["apple","banana","orange","grape"]

# %%
type(fruits)
# Out:
# list

# %%
fruits[3]
# Out:
# 'grape'

# %%
len(fruits)
# Out:
# 4

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'grape']

# %%
lst1=[1,3,5,7,9]

# %%
lst1
# Out:
# [1, 3, 5, 7, 9]

# %%
fruits[0]="pineapple"
fruits
# Out:
# ['pineapple', 'banana', 'orange', 'grape']

# %%
lst2=[2,3,4,6,8,5]

# %%
print(lst2)
# Out:
# [2, 3, 4, 6, 8, 5]

# %%
lst3=['apple',3,3.2,8-8j]

# %%
lst3
# Out:
# ['apple', 3, 3.2, (8-8j)]

# %%
type(lst3[2])
# Out:
# float
