# %% [markdown]
# # Comments and Documentation/Docstrings

# %% [markdown]
# ## Comments

# %%
#This function calculates the are of a rectangle
""" Calculates the area by multiplying length and width."""

# %% [markdown]
# ## Documentation is functions

# %%
def square_number(number):
    """
    this is 
    a function 

    so its basically doing operations inside this 
    fucntion



    """
    return number**2

# %%
square_number(4)
# Out:
# 16

# %%
print(square_number.__doc__)
# Out:
# this is
# a function
#
# so its basically doing operations inside this
# fucntion
