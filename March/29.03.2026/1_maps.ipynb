# %% [markdown]
# # Maps

# %%
def square(x):
    return x**2
numbers=[1,2,3,4,5,6]
square_numbers=list(map(square,numbers))
square_numbers
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
def multiply(a,b):
    return a*b
numbers=[1,2,3,4,5,6]
numbers2=[3,5,2,7,9,2]
multiply_nums=list(map(multiply,numbers,numbers2))
multiply_nums
# Out:
# [3, 10, 6, 28, 45, 12]
