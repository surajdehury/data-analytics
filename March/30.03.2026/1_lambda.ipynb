# %% [markdown]
# # Lambda

# %%
lambda x:x*x
# Out:
# <function __main__.<lambda>(x)>

# %%
def square(x):
    return x*x

# %%
square(5)
# Out:
# 25

# %%
square2=lambda x:x*x
square2(5)
# Out:
# 25

# %%
def multi(a,b):
    return a*b

# %%
multi(5,3)
# Out:
# 15

# %%
mul2=lambda a,b:a*b
mul2(5,3)
# Out:
# 15
