# %% [markdown]
# ## Python Comparison operators:

# %%
#<,<=,>,>=,==,!=

# %% [markdown]
# ## Conditional Statements ##

# %%
#If,else,elif,switch,Nested

# %%
# Iterate different data structure using loops
