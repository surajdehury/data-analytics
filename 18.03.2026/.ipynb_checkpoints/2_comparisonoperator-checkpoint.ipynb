# %% [markdown]
# # Comparison Operator

# %%
5<10
# Out:
# True

# %%
5<=10
# Out:
# True

# %%
5>10
# Out:
# False

# %%
5==10
# Out:
# False

# %%
5!=10
# Out:
# True

# %%
5>=10
# Out:
# False

# %%
4<4
# Out:
# False

# %%
4<=4
# Out:
# True

# %%
4>4
# Out:
# False

# %%
4>=4
# Out:
# True

# %%
4==4
# Out:
# True

# %%
4!=4
# Out:
# False

# %%
'Hello'=='Hello'
# Out:
# True

# %%
'Hello'=='hello'
# Out:
# False

# %%
[1,2,3]==[1,2,3]
# Out:
# True

# %%
[1,2,3]==[1,3,2]
# Out:
# False

# %%
{1,2,3}=={1,3,2} #set unordered data type
# Out:
# True

# %%
1 in [2,4,6]
# Out:
# False

# %%
2 in [2,4,6]
# Out:
# True

# %%
2 not in [2,4,6]
# Out:
# False

# %%
2 in {2,4,6,8}
# Out:
# True

# %%
'a' in{'a':2,'b':4}
# Out:
# True

# %%
'c' in{'a':2,'b':4}
# Out:
# False
