# %%
"""Python supports Function Overloading.
  TRUE 
  False 
You have selected an correct response.
 
Question 2
0 / 0 pts
Which is an OOP concept?
  inheritance 
  polymorphism 
  abstraction 
  All the above 
You have selected the correct response.
 
Incorrect
Question 3
0 / 0 pts
Which of the statement is correct?
  A class is an instance of an object 
  A class and an object are the same thing 
  An object is an instance of a class 
  A class and an object are not related to each other 
You have selected an incorrect response.
 
Incorrect
Question 4
0 / 0 pts
In inheritance:
  A class imports values of all the parent class 
  An object imports all values of a parent class 
  An object imports all values of a parent object 
  None of the above 
You have selected an incorrect response.
 
Question 5
0 / 0 pts
Which type of Programming does Python support?
  object-oriented programming 
  structured programming 
  functional programming 
  All of the above 
You have selected the correct response.
 
Question 6
0 / 0 pts
There is an object 'Car' having an attribute 'Mileage'. How to access this attribute?
  Car['Mileage'] 
  Car[Mileage] 
  Car.Mileage 
You have selected the correct response.
  Car(Mileage) 
 
Question 7
0 / 0 pts
How many objects can be generated by a class in python?
  1 
  1024 
  Infinite 
You have selected the correct response.
  None of the above 
 
Question 8
0 / 0 pts
The function used to initialize the values of an object during instantiation for a class 'B':
  B() 
You have selected the correct response.
  __init__() 
  init() 
  None of the above 
 
Question 9
0 / 0 pts
What does the keyword 'self' represent?
  The class itself 
  the object itself 
You have selected the correct response.
  the runtime instance itself 
  None of the above 
 
Question 10
0 / 0 pts
Which keyword is used to create an empty code block?
  break 
  continue 
  pass 
You have selected the correct response.
  empty 
 
Question 11
0 / 0 pts
Self is the first parameter of every python class function.
  TRUE 
You have selected the correct response.
  False """
