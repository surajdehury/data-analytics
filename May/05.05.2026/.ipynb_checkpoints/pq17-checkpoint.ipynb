# %%
""" Which of the following statements is one of the ways to install third-party packages in Python?
  py install 
  import 
  pip install 
You have selected the correct response.
  pip download 
 
Question 2
0 / 0 pts
Which is the right statement for using third-party codes in your projects in Python?
  pip 
  import 
You have selected the correct response.
  install 
  download 
 
Question 3
0 / 0 pts
Which statement is used to completely remove third-party packages using Python?
  pip remove 
  pip uninstall 
You have selected the correct response.
  remove package 
  pack uninstall 
 
Question 4
0 / 0 pts
What does the pip freeze command help with?
  It makes the installed package unusable for any projects in Python 
  It provides the list of all the installed packages in the system 
You have selected the correct response.
  It is used to uninstall a package 
  None of the above 
 
Question 5
0 / 0 pts
Which command is used to list the dependencies from other packages?
  pip show 
You have selected the correct response.
  pip list 
  pip request 
  None of the above 
 
Question 6
0 / 0 pts
Which of the following statements is true?

A. A module is a file containing Python code.

B. The file name of a module ends with the .mod extension.

C. A module contains many packages within those.

  Only A is true 
You have selected the correct response. Only the first statement is true. A module in python ends with .py extension. A package can contain mutiple modules inside, not vice versa.
  Both A and B are true 
  Both A and C are true 
  All of the statements are true 
 
Question 7
0 / 0 pts
Consider the following code is saved as a module named "car_module.py" and is imported to access the dictionary.

Car = {"Brand": "Honda", "Model": "Civic", "Colour": "Black"}

import car_module

a = car_module.car["Model"]

print(a)

What will be the output?

  Model: Civic 
  HondaCivicBlack 
  Civic 
You have selected the correct response.
  Brand: HondaModel: CivicColour: Black 
 
Incorrect
Question 8
0 / 0 pts
Which of the following statements is true?

A. Modules allow for the reuse of codes.

B. Individual functions can be imported from a module without importing the whole module.

  Only A is true 
  Only B is true 
  Both A and B are true 
You have selected an incorrect response.
  Neither A nor B is true 
 
Question 9
0 / 0 pts
Which of the following files is mandatory to be included in a package?
  __init__.py 
You have selected the correct response. __init.py__ differentiates a regular folder and a package.
  py.main 
  __main.py__ 
  init.package 
 
Question 10
0 / 0 pts
Which of the following statements is true?

1. When __name__ is set as __main__, the file is being run as the main program.

2. When __name__ is set to the module name, the file is being imported from another module.

3. If __name__ == "__main__" allows or prevents a code from being run when the modules are imported.

  Only A and B are true 
  Only A and C are true 
  Only B and C are true 
  All three statements are true 
You have selected the correct response. All the three statements are true.
 
Question 11
0 / 0 pts
If we import the function of square root (sqrt) from the module math, from math import sqrt what will be the statement to get the output to the square root of 64?
  print (math.sqrt(64)) 
  print(sqrt(64)) 
You have selected the correct response.
  Either of the above two options can be used 
  Neither of the two options can be used """
