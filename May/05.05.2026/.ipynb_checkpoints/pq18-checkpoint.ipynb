# %%
"""Question 1
0 / 0 pts
Which of the following is not a keyword as part of exception catching and handling in Python?
  test 
You have selected the correct response. The test is not a keyword for exception handling in Python.
  except 
  finally 
  try 
 
Unanswered
Question 2
0 / 0 pts
Which of the following has the wrong flow of Exception handling?
  Try --> Finally ---> Except 
  Try --> Except ---> Finally 
  Try ---> Except ---> Else 
  Try ---> Except ---> Else ---> Finally 
 
Question 3
0 / 0 pts
Which block is used to handle exceptions?
  Try 
  Except 
You have selected the correct response. Except block handles exceptions.
  Else 
  Finally 
 
Question 4
0 / 0 pts
State whether the statement is true or false.

While checking for errors in a code, the Try block cannot function independently and should always be followed by an Except or a Finally block.

  TRUE 
You have selected the correct response. The given statement is true.
  FALSE 
 
Question 5
0 / 0 pts
In exception handling, which of the following blocks will execute only when there are no exceptions?
  Finally 
  Try 
  Else 
You have selected the correct response.
  All of the above 
 
Question 6
0 / 0 pts
What will be the output?

num_1 = 23

num_2 = 0

try:

  num_1/num_2

finally:

  print ("This will continue to run")

except ZeroDivisionError:

  print ("Cannot divide by zero")

  Cannot divide by zeroThis will continue to run 
  This will continue to run 
  Cannot divide by zero 
  Syntax Error 
You have selected the correct response. The code will return an error because the order of code blocks should be Try --> Except --> Finally.
 
Question 7
0 / 0 pts
______ is a python object that represents an error.
  Package 
  Exception 
You have selected the correct response.
  Main 
  Condition 
 
Question 8
0 / 0 pts
What will the following code result in?

number_1 = input("Enter a number:")

number_2 = 2

sum = int(number_1)+number_2

print(sum)

 

Enter a number: four

  TypeError 
  ValueError 
You have selected the correct response. The input "four" is a string which can't be converted to an integer.
  KeyError 
  6 
 
Question 9
0 / 0 pts
Which module in python is used to test a unit of code to detect and fix errors?
  maintest 
  keytest 
  pairtest 
  unittest 
You have selected the correct response.
 
Question 10
0 / 0 pts
Which is not a possible outcome in unit testing using the unittest module?
  OK 
  SUCCESS 
You have selected the correct response.
  FAIL 
  ERROR 
 
Question 11
0 / 0 pts
State which of the following is true or false.

A. Nested function is a function inside another function

B. Unless the main function is called, the nested functions will not execute

  TRUE and TRUE 
You have selected the correct response.
  TRUE and FALSE 
  FALSE and TRUE 
  FALSE and FALSE 
 
Question 12
0 / 0 pts
What will be the output?

def num():

  num1 = 20

  num2 = 5

  def sum():

    print(num1+num2)

  sum()

  20 
  5 
  25 
  No Output 
"""
