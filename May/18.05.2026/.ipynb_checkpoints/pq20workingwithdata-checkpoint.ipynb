# %%
#practise

# %%
"""Question 10 pts
Question 1
0 / 0 pts
The join() function combines two DataFrames by index. The merge() function combines two DataFrames by the specified column.
  TRUE 
You have selected the correct response. The join function joins two dataframes based on their indexes, however, the merge method is more flexible, allowing us to select columns other than the index to join on for both dataframes.
  FALSE 
 
Question 2
0 / 0 pts
If the columns have a single level, the output of the stack operation is a ________.
  Data Frame 
  Series 
You have selected the correct response.
  Value 
  List 
 
Question 3
0 / 0 pts
DataFrame.stack(level=___) In the "stack" syntax, if the level is not specified, it will take which header into consideration.
  Inner most level 
You have selected the correct response. If the level in the stack function is not specified, the innermost level is taken into consideration.
  Outermost level 
  Can't say 
 
Question 4
0 / 0 pts
df.isnull() returns a data frame with "True" in the place of Null/NaN cells, and "False" in place of other cells. Whereas in the case of df.notnull() it's vice versa.
  TRUE 
You have selected the correct response. Isnull() , notnull() functions are used to indentify the null cells in the data frame.
  FALSE 
 
Question 5
0 / 0 pts
Split, Apply, and Combine actions take place in which of the following Pandas function on a data frame df?
  df.groupby() 
You have selected the correct response.
  df.pivot() 
  df.concat() 
  df.crosstab() 
 
Question 6
0 / 0 pts
State whether the given statement is True or False.

"A lambda function is an anonymous function that may be passed without having to define it like a conventional function".

  TRUE 
You have selected the correct response.
  FALSE 
 
Question 7
0 / 0 pts
Which line of code returns an array of "10" random integers from 1 to 100, both included?
  arr = df.random.randint(1, 101, 10) 
You have selected the correct response. This function helps in generating the random integers in the given from and to the range.
  arr = df.random.randint(1, 100, 10) 
  arr = df.random.randint(1, 10, 100) 
 
Question 8
0 / 0 pts
Which of the code create a new column with elements in "Array", in a data frame "df"?
  df1 = df.assign(New_column=Array) 
  df['New_column'] = Array 
  Both 1 and 2 
You have selected the correct response. Both the methods can create a new column in the data frame
  df1 = df.apply(New_column=Array) 
 
Question 9
0 / 0 pts
Create a list of 10 consecutive squares for integer "n" using list comprehension.
  new_list=[]for i in range(n,n+9): new_list.append(n**2) 
  new_list=[n**2 for n in range(n,n+9)] 
  new_list=[n**2 for n in range(n,n+10)] 
You have selected the correct response.
  Both 1 and 2 
 
Question 10
0 / 0 pts
Match the following:

1.df.interpolate()                                 A. Filling null value with the next ones

2.df.fillna(value)                                  B. Fills the missing values using the linear method

3.df.fillna(method='pad/ffill')             C. Filling null values with a single value

4.df.fillna(method='bfill')                    D. Filling null value with the previous ones

  
1-A

2-B

3-C

4-D

  
1-B

2-C

3-D

4-A

1.df.interpolate()----------------Fills the missing values using linear method.

2.df.fillna(value)---------------- Filling null values with a single value.

3.df.fillna(method='pad')--------- Filling null value with the previous ones.

4.df.fillna(method='bfill')------- Filling null value with the next ones.

  
1-D

2-B

3-C

4-A

  
1-B

2-A

3-C

4-D
Question 14
0 / 0 pts
Consider the syntax pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='___')

In the pivot table syntax, what is the default aggregate function input?

  mean 
You have selected the correct response. Mean is the default aggregate function.
  sum 
  std dev 
  No defaults. Need to be specified """
