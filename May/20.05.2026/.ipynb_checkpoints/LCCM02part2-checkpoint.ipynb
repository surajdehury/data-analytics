# %%
import pandas as pd
data=pd.read_csv('basic_salary_2.csv')

# %%
data.head(5)
# Out:
#   First_Name Last_Name Grade Location     ba       ms
# 0      Sagar    Chavan   GR2   MUMBAI  13390   6700.0
# 1      Aaron     Jones   GR1   MUMBAI  23280  13490.0
# 2       John     Patil   GR2   MUMBAI  13500  10760.0
# 3      Sneha     Joshi   GR1    DELHI  20660      NaN
# 4     Gaurav     Singh   GR2    DELHI  13760  13220.0

# %%
data.shape
# Out:
# (7, 6)

# %%
data.isnull().sum()
# Out:
# First_Name    0
# Last_Name     0
# Grade         0
# Location      0
# ba            0
# ms            1
# dtype: int64

# %%
#fill that na with median
n=data['ms'].median()
data['ms']=data['ms'].fillna(n)
print(n)
# Out:
# 9320.0

# %%
data.head(5)
# Out:
#   First_Name Last_Name Grade Location     ba       ms
# 0      Sagar    Chavan   GR2   MUMBAI  13390   6700.0
# 1      Aaron     Jones   GR1   MUMBAI  23280  13490.0
# 2       John     Patil   GR2   MUMBAI  13500  10760.0
# 3      Sneha     Joshi   GR1    DELHI  20660   9320.0
# 4     Gaurav     Singh   GR2    DELHI  13760  13220.0

# %%
data['Location'].value_counts()
# Out:
# Location
# MUMBAI    4
# DELHI     3
# Name: count, dtype: int64

# %%
#descriptive statistics
data.describe()
# Out:
#                  ba            ms
# count      7.000000      7.000000
# mean   15744.285714   9744.285714
# std     4361.444169   2843.142962
# min    11960.000000   6700.000000
# 25%    13445.000000   7360.000000
# 50%    13660.000000   9320.000000
# 75%    17210.000000  11990.000000
# max    23280.000000  13490.000000

# %%
import matplotlib.pyplot as plt
data_ba=data.ba
plt.boxplot(data_ba)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x111d27250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x111d274d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x111d27110>],
#  'medians': [<matplotlib.lines.Line2D at 0x111d27750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x111d27890>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
data_ms=data.ms
plt.boxplot(data_ms)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1139816d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x113981950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x113981590>],
#  'medians': [<matplotlib.lines.Line2D at 0x113981bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x113981d10>],
#  'means': []}

# %%
data.head(3)
# Out:
#   First_Name Last_Name Grade Location     ba       ms
# 0      Sagar    Chavan   GR2   MUMBAI  13390   6700.0
# 1      Aaron     Jones   GR1   MUMBAI  23280  13490.0
# 2       John     Patil   GR2   MUMBAI  13500  10760.0

# %%
A=data[data['Location']=='MUMBAI']
print(A)
# Out:
#   First_Name Last_Name Grade Location     ba       ms
# 0      Sagar    Chavan   GR2   MUMBAI  13390   6700.0
# 1      Aaron     Jones   GR1   MUMBAI  23280  13490.0
# 2       John     Patil   GR2   MUMBAI  13500  10760.0
# 6       Anup      Save   GR2   MUMBAI  11960   7880.0

# %%
B=data[data['ba']>13000]
print(B)
# Out:
#   First_Name Last_Name Grade Location     ba       ms
# 0      Sagar    Chavan   GR2   MUMBAI  13390   6700.0
# 1      Aaron     Jones   GR1   MUMBAI  23280  13490.0
# 2       John     Patil   GR2   MUMBAI  13500  10760.0
# 3      Sneha     Joshi   GR1    DELHI  20660   9320.0
# 4     Gaurav     Singh   GR2    DELHI  13760  13220.0
# 5      Adela    Thomas   GR2    DELHI  13660   6840.0

# %%
min=data['ba'].agg('min')
print(min)
# Out:
# 11960

# %%
max=data['ba'].agg('max')
print(max)
# Out:
# 23280

# %%
mean=data['ba'].agg('mean')
print(mean)
# Out:
# 15744.285714285714

# %%
C=data['ba'].agg(['min','max','mean'])
print(C)
# Out:
# min     11960.000000
# max     23280.000000
# mean    15744.285714
# Name: ba, dtype: float64

# %%
m=data['Grade'].mode()
print(m)
# Out:
# 0    GR2
# Name: Grade, dtype: object

# %% [markdown]
# ## Writing a text file

# %%
file=open('okay.txt','w')
file.write("Hello my name is Suraj\n")
# Out:
# 23

# %%
file.close()

# %%
file=open('okay.txt','r')
txt=file.read()
print(txt)
# Out:
# Hello my name is Suraj

# %%
file=open('okay.txt','a')
file.write("I have completed my M.Tech")
# Out:
# 26

# %%
file.write("\nGoing to be graduated very soon")
file.close()

# %%
file=open('abs.txt','x')
file.write("I have abs")
file.close()
