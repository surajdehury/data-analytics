# %%
import pandas as pd
data=pd.read_csv('data_clean.csv')

# %%
data.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data.head(2)
# Out:
#    Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     67     5    1  2010    67       S
# 1   36.0    118.0   8.0     72     5    2  2010    72       C

# %%
data=data.drop('Temp C',axis=1)

# %%
data.head(2)
# Out:
#    Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     5    1  2010    67       S
# 1   36.0    118.0   8.0     5    2  2010    72       C

# %%
data['Month'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Ozone'].isnull().sum()
# Out:
# np.int64(38)

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')

# %%
data['Month'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Month']=data['Month'].fillna(5)

# %%
data['Month'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Temp']=pd.to_numeric(data['Temp'],errors='coerce')

# %%
data['Temp'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Weather']=data['Weather'].astype('category')

# %%
data['Weather'].isnull().sum()
# Out:
# np.int64(3)

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
#Duplicated data
data[data.duplicated()].shape
# Out:
# (1, 8)

# %%
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1=data.drop_duplicates()#removing duplicate data

# %%
data1[data1.duplicated()].shape
# Out:
# (0, 8)

# %%
data1.head(4)
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4    5.0    1  2010    67       S
# 1   36.0    118.0   8.0    5.0    2  2010    72       C
# 2   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3   18.0    313.0  11.5    5.0    4  2010    62       S

# %%
#renaming the file
data2=data1.rename({'Solar.R':'Solar'},axis=1)

# %%
data2.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3   18.0  313.0  11.5    5.0    4  2010    62       S
# 4    NaN    NaN  14.3    5.0    5  2010    56       S

# %%
data2.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
#impuatation

# %%
m=data2['Ozone'].mean()

# %%
print(m)
# Out:
# 41.81512605042017

# %%
data2['Ozone']=data2['Ozone'].fillna(m)

# %%
#
n=data2['Weather'].mode().iloc[0]

# %%
print(n)
# Out:
# S

# %%
data2['Weather']=data2['Weather'].fillna(n)

# %%
data2.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
o=data2['Solar'].mean()
print(o)
# Out:
# 185.36666666666667

# %%
data2['Solar']=data2['Solar'].fillna(o)

# %%
data2.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
#Box plot
import matplotlib.pyplot as plt
data_box=data1.dropna()
data1_box=data_box.Ozone
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x110915590>,
#   <matplotlib.lines.Line2D at 0x1109156d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x110915810>,
#   <matplotlib.lines.Line2D at 0x110915950>],
#  'boxes': [<matplotlib.lines.Line2D at 0x110839450>],
#  'medians': [<matplotlib.lines.Line2D at 0x110915a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x110915bd0>],
#  'means': []}
