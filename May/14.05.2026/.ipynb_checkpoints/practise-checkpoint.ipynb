# %%
import pandas as pd
data=pd.read_csv('data_clean.csv')

# %%
data0=data

# %%
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     67     5    1  2010    67       S
# 1   36.0    118.0   8.0     72     5    2  2010    72       C
# 2   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3   18.0    313.0  11.5     62     5    4  2010    62       S
# 4    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data=data.drop('Temp C',axis=1)

# %%
data.head(2)
# Out:
#    Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     5    1  2010    67       S
# 1   36.0    118.0   8.0     5    2  2010    72       C

# %%
data=data.rename({'Solar.R':'Solar'},axis=1)

# %%
data.head(2)
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4     5    1  2010    67       S
# 1   36.0  118.0   8.0     5    2  2010    72       C

# %%
data1=data

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4     5    1  2010    67       S
# 1   36.0  118.0   8.0     5    2  2010    72       C
# 2   12.0  149.0  12.6     5    3  2010    74      PS
# 3   18.0  313.0  11.5     5    4  2010    62       S
# 4    NaN    NaN  14.3     5    5  2010    56       S

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data['Ozone'].isnull().sum()
# Out:
# np.int64(38)

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')

# %%
data['Month']=data['Month'].fillna(5)

# %%
data['Temp'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Temp']=pd.to_numeric(data['Temp'],errors='coerce')

# %%
data['Temp'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Weather']=data['Weather'].astype('category')

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3   18.0  313.0  11.5    5.0    4  2010    62       S
# 4    NaN    NaN  14.3    5.0    5  2010    56       S

# %%
m=data1['Ozone'].mean()
data1['Ozone']=data1['Ozone'].fillna(m)
data1['Ozone'].isnull().sum()
# Out:
# np.int64(0)

# %%
n=data1['Solar'].mean()
data1['Solar']=data1['Solar'].fillna(n)
data1['Solar'].isnull().sum()
# Out:
# np.int64(0)

# %%
o=data1['Weather'].mode().iloc[0]
data1['Weather']=data1['Weather'].fillna(o)
data1['Weather'].isnull().sum()
# Out:
# np.int64(0)

# %%
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
#Outlier
#box plot

# %%
import matplotlib.pyplot as plt
data_box=data0.dropna()
data1_box=data_box.Ozone
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10cb5bd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10cc18050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10cb5bc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x10cc182d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10cc18410>],
#  'means': []}

# %%
data0.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %% [markdown]
# ## Yesterday

# %%
data1.head(5)
# Out:
#        Ozone       Solar  Wind  Month  Day  Year  Temp Weather
# 0  41.000000  190.000000   7.4    5.0    1  2010    67       S
# 1  36.000000  118.000000   8.0    5.0    2  2010    72       C
# 2  12.000000  149.000000  12.6    5.0    3  2010    74      PS
# 3  18.000000  313.000000  11.5    5.0    4  2010    62       S
# 4  41.583333  185.403974  14.3    5.0    5  2010    56       S

# %%
data2 = pd.get_dummies(data1, columns=['Weather'], dtype=int)

# %%
data2.head(5)
# Out:
#        Ozone       Solar  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0  41.000000  190.000000   7.4    5.0    1  2010    67          0           0
# 1  36.000000  118.000000   8.0    5.0    2  2010    72          1           0
# 2  12.000000  149.000000  12.6    5.0    3  2010    74          0           1
# 3  18.000000  313.000000  11.5    5.0    4  2010    62          0           0
# 4  41.583333  185.403974  14.3    5.0    5  2010    56          0           0
#
#    Weather_S
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1

# %% [markdown]
# ## Convert whole dataset into numeric

# %%
#2 ways-
#1)MinMax Scaler
#2)Standars Scaler

# %%
#MinMax Scaler
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
array=data2.values
array
# Out:
# array([[ 41.        , 190.        ,   7.4       , ...,   0.        ,
#           0.        ,   1.        ],
#        [ 36.        , 118.        ,   8.        , ...,   1.        ,
#           0.        ,   0.        ],
#        [ 12.        , 149.        ,  12.6       , ...,   0.        ,
#           1.        ,   0.        ],
#        ...,
#        [ 41.58333333, 145.        ,  13.2       , ...,   0.        ,
#           0.        ,   1.        ],
#        [ 14.        , 191.        ,  14.3       , ...,   0.        ,
#           0.        ,   1.        ],
#        [ 18.        , 131.        ,   8.        , ...,   1.        ,
#           0.        ,   0.        ]], shape=(158, 10))

# %%
scaler=MinMaxScaler(feature_range=(0,1))
rescaledX=scaler.fit_transform(array)
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.24 0.56 0.3  0.   0.   0.   0.27 0.   0.   1.  ]
#  [0.21 0.34 0.33 0.   0.03 0.   0.39 1.   0.   0.  ]
#  [0.07 0.43 0.57 0.   0.07 0.   0.44 0.   1.   0.  ]
#  [0.1  0.94 0.52 0.   0.1  0.   0.15 0.   0.   1.  ]
#  [0.24 0.55 0.66 0.   0.13 0.   0.   0.   0.   1.  ]]

# %% [markdown]
# # Standard Scaler

# %%
from numpy import set_printoptions
from sklearn.preprocessing import StandardScaler

# %%
array=data2.values
scaler=StandardScaler()
scaler.fit(array)
# Out:
# StandardScaler()

# %%
rescaledx=scaler.transform(array)

set_printoptions(precision=2)
print(rescaledx[0:5, :])
# Out:
# [[-2.06e-02  5.32e-02 -7.31e-01 -1.42e+00 -1.67e+00  0.00e+00 -1.15e+00
#   -6.70e-01 -6.51e-01  1.24e+00]
#  [-1.97e-01 -7.80e-01 -5.59e-01 -1.42e+00 -1.56e+00  0.00e+00 -6.13e-01
#    1.49e+00 -6.51e-01 -8.04e-01]
#  [-1.04e+00 -4.21e-01  7.55e-01 -1.42e+00 -1.45e+00  0.00e+00 -3.99e-01
#   -6.70e-01  1.54e+00 -8.04e-01]
#  [-8.33e-01  1.48e+00  4.41e-01 -1.42e+00 -1.34e+00  0.00e+00 -1.68e+00
#   -6.70e-01 -6.51e-01  1.24e+00]
#  [-2.51e-16  0.00e+00  1.24e+00 -1.42e+00 -1.23e+00  0.00e+00 -2.32e+00
#   -6.70e-01 -6.51e-01  1.24e+00]]
